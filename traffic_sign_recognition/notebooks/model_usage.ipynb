# %%
from ultralytics import YOLO
from ultralytics.engine.results import Results

model = YOLO("../model/best.pt")

results = model.predict("../../test_film.mp4", save = True) # video is saved to runs/detect/predict/test_film.avi

#results = model("../../test_film.mp4", stream = True)

# result: Results
# for result, index in enumerate(results):
#     result.save(f"{index}.jpg")
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/732) /workspaces/Machine-Learning-basics/traffic_sign_recognition/notebooks/../../test_film.mp4: 384x640 3 cars, 11.9ms
# video 1/1 (frame 2/732) /workspaces/Machine-Learning-basics/traffic_sign_recognition/notebooks/../../test_film.mp4: 384x640 3 cars, 15.3ms
# video 1/1 (frame 3/732) /workspaces/Machine-Learning-basics/traffic_sign_recognition/notebooks/../../test_film.mp4: 384x640 3 cars, 13.8ms
# ...
